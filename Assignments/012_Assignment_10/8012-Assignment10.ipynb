# %% [raw]
# Q. Indians and elections are the things which keeps on happening almost every month and every year.
# Well, Loksabha elections is one such which happens after every 5 years, well we have data of
# candidates and electors from 2009 and 2014. Compare the dataset and compute the results visually
# 1. Create grand alliances
# a. 'INC','NCP', 'RJD', 'DMK', 'IUML',
# 'JMM','JD(s)','KC(M)','RLD','RSP','CMP(J)','KC(J)','PPI','MD' as UPA
# b. 'BJP','SS', 'LJP', 'SAD', 'RLSP',
# 'AD','PMK','NPP','AINRC','NPF','RPI(A)','BPF','JD(U)','SDF','NDPP','MNF','RIDALOS','KM
# DK','IJK','PNK','JSP','GJM','MGP','GFP','GVP','AJSU','IPFT','MPP','KPP','JKPC','KC(T)','BDJ
# S','AGP','JSS','PPA','UDP','HSPDP','PSP','JRS','KVC','PNP','SBSP','KC(N)','PDF','MDPF' as
# NDA
# c. 'YSRCP','AAAP', 'IND', 'AIUDF', 'BLSP', 'JKPDP', 'JD(S)', 'INLD', 'CPI', 'AIMIM',
# 'KEC(M)','SWP', 'NPEP', 'JKN', 'AIFB', 'MUL', 'AUDF', 'BOPF', 'BVA', 'HJCBL',
# 'JVM','MDMK' as Others
# 2. Create Winning seats distribution by Major Political Parties & Alliances for 2009 & 2014
# 3. How many seats won by Alliances and Major Political Parties ?
#
# 4. Plot comparatively seats won based on candidate category as General, ST and SC for 2009 &
# 2014
# 5. Plot the age distribution of winners of both 2014 and 2009 elections
# 6. Separately plot age distribution of NDA & UPA candidates
# 7. Plot Gender distributions of 2009 & 2014 elections
# 8. Plot gender distribution of NDA and UPA separately for 2009 elections
# 9. Plot gender distribution of NDA and UPA separately for 2014 elections
# 10. Plot the poll percentage of states for 2009 & 2014 elections

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("LS2009Candidate.csv")
df1
# Out:
#      ST_CODE      State name  Month  Year  PC Number     PC name PC Type  \
# 0        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 1        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 2        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 3        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 4        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# ...      ...             ...    ...   ...        ...         ...     ...
# 8065     U07      Puducherry      3  2009          1  Puducherry     GEN
# 8066     U07      Puducherry      3  2009          1  Puducherry     GEN
# 8067     U07      Puducherry      3  2009          1  Puducherry     GEN
# 8068     U07      Puducherry      3  2009          1  Puducherry     GEN
# 8069     U07      Puducherry      3  2009          1  Puducherry     GEN
#
#               Candidate Name Candidate Sex Candidate Category  Candidate Age  \
# 0              RATHOD RAMESH             M                 ST           43.0
# 1              KOTNAK RAMESH             M                 ST           39.0
# 2            MESRAM NAGO RAO             M                 ST           59.0
# 3                ADE TUKARAM             M                 ST           55.0
# 4       RATHOD SADASHIV NAIK             M                 ST           50.0
# ...                      ...           ...                ...            ...
# 8065        DR. R. NARAYANAN             M                GEN           59.0
# 8066  MUPPADAI MATHIMAHARAJA             M                GEN           45.0
# 8067         MURUGAIYAN. K.S             M                GEN           42.0
# 8068              I.M. SEKAR             M                GEN           46.0
# 8069     MOHAMED YOUSUF. S.A             M                GEN           46.0
#
#      Party Abbreviation  Total Votes Polled  Position
# 0                   TDP            372268.0       1.0
# 1                   INC            257181.0       2.0
# 2                  PRAP            112930.0       3.0
# 3                   BJP             57931.0       4.0
# 4                   BSP             16471.0       5.0
# ...                 ...                 ...       ...
# 8065                IND               422.0      24.0
# 8066                IND               378.0      25.0
# 8067                IND               378.0      26.0
# 8068                IND               375.0      27.0
# 8069                IND               298.0      28.0
#
# [8070 rows x 14 columns]

# %%
df2 = pd.read_csv("LS2009Electors.csv")
df2
# Out:
#     STATE CODE           STATE  PC NO PARLIAMENTARY CONSTITUENCY  \
# 0          S01  Andhra Pradesh      1                   Adilabad
# 1          S01  Andhra Pradesh      2                 Peddapalle
# 2          S01  Andhra Pradesh      3                 Karimnagar
# 3          S01  Andhra Pradesh      4                  Nizamabad
# 4          S01  Andhra Pradesh      5                  Zahirabad
# ..         ...             ...    ...                        ...
# 538        U05    NCT OF Delhi      5          NORTH WEST  DELHI
# 539        U05    NCT OF Delhi      6                WEST  DELHI
# 540        U05    NCT OF Delhi      7                SOUTH DELHI
# 541        U06     Lakshadweep      1                Lakshadweep
# 542        U07      Puducherry      1                 Puducherry
#
#      Total voters  Total_Electors  TOT_CONTESTANT  POLL PERCENTAGE
# 0          864165         1131211               9            76.39
# 1          905332         1315642              15            68.81
# 2          990646         1496211              15            66.21
# 3          891508         1333271              12            66.87
# 4         1017372         1359566              10            74.83
# ..            ...             ...             ...              ...
# 538        857545         1798181              16            47.69
# 539        884168         1687727              15            52.39
# 540        731314         1542412              15            47.41
# 541         39498           45983               4            85.90
# 542        608509          762440              28            79.81
#
# [543 rows x 8 columns]

# %%
df3 = pd.read_csv("LS2014Candidate.csv")
df3
# Out:
#      ST_CODE      State name  Month  Year  PC Number     PC name PC Type  \
# 0        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# 1        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# 2        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# 3        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# 4        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# ...      ...             ...    ...   ...        ...         ...     ...
# 8789     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8790     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8791     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8792     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8793     U07      Puducherry      5  2014          1  Puducherry     GEN
#
#                     Candidate Name Candidate Sex Candidate Category  \
# 0                     GODAM NAGESH             M                 ST
# 1                           NARESH             M                 ST
# 2                    RAMESH RATHOD             M                 ST
# 3                  RATHOD SADASHIV             M                 ST
# 4                 NETHAWATH RAMDAS             M                 ST
# ...                            ...           ...                ...
# 8789          PUVALA NAGESWARA RAO             M                GEN
# 8790                     G. PALANI             M                GEN
# 8791            MARIE UTHRIANATHAN             M                GEN
# 8792                 S. CHITRAKALA             F                GEN
# 8793  P. DHANARASU @ MATHIMAHARAJA             M                GEN
#
#       Candidate Age Party Abbreviation  Total Votes Polled  Position
# 0              49.0                TRS              430847         1
# 1              37.0                INC              259557         2
# 2              48.0                TDP              184198         3
# 3              55.0                BSP               94420         4
# 4              44.0                IND               41032         5
# ...             ...                ...                 ...       ...
# 8789           60.0                IND                 465        27
# 8790           59.0         CPI(ML)(L)                 438        28
# 8791           32.0                SAP                 366        29
# 8792           37.0              JD(U)                 309        30
# 8793           50.0                IND                 198        31
#
# [8794 rows x 14 columns]

# %%
df4 = pd.read_csv("LS2014Electors.csv")
df4
# Out:
#     STATE CODE           STATE  PC NO      PARLIAMENTARY CONSTITUENCY  \
# 0          S01  Andhra Pradesh      1                       Adilabad
# 1          S01  Andhra Pradesh      2                     Peddapalle
# 2          S01  Andhra Pradesh      3                     Karimnagar
# 3          S01  Andhra Pradesh      4                       Nizamabad
# 4          S01  Andhra Pradesh      5                       Zahirabad
# ..         ...             ...    ...                             ...
# 538        U05    NCT OF Delhi      5  NORTH WEST DELHI
# 539        U05    NCT OF Delhi      6  WEST DELHI
# 540        U05    NCT OF Delhi      7  SOUTH DELHI
# 541        U06     Lakshadweep      1                     Lakshadweep
# 542        U07      Puducherry      1                      Puducherry
#
#      Total voters  Total_Electors  POLL PERCENTAGE
# 0         1055593         1386282            76.15
# 1         1025194         1425355            71.93
# 2         1127225         1550810            72.69
# 3         1034032         1496193            69.11
# 4         1099784         1445354            76.09
# ..            ...             ...              ...
# 538       1356404         2194343            61.81
# 539       1348744         2039410            66.13
# 540       1102849         1752748            62.92
# 541         43242           49922            86.62
# 542        740053          901357            82.10
#
# [543 rows x 7 columns]

# %%
#Concatenating Candidate Data
dfC = pd.concat([df1, df3], axis = 0)
dfC
# Out:
#      ST_CODE      State name  Month  Year  PC Number     PC name PC Type  \
# 0        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 1        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 2        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 3        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 4        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# ...      ...             ...    ...   ...        ...         ...     ...
# 8789     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8790     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8791     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8792     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8793     U07      Puducherry      5  2014          1  Puducherry     GEN
#
#                     Candidate Name Candidate Sex Candidate Category  \
# 0                    RATHOD RAMESH             M                 ST
# 1                    KOTNAK RAMESH             M                 ST
# 2                  MESRAM NAGO RAO             M                 ST
# 3                      ADE TUKARAM             M                 ST
# 4             RATHOD SADASHIV NAIK             M                 ST
# ...                            ...           ...                ...
# 8789          PUVALA NAGESWARA RAO             M                GEN
# 8790                     G. PALANI             M                GEN
# 8791            MARIE UTHRIANATHAN             M                GEN
# 8792                 S. CHITRAKALA             F                GEN
# 8793  P. DHANARASU @ MATHIMAHARAJA             M                GEN
#
#       Candidate Age Party Abbreviation  Total Votes Polled  Position
# 0              43.0                TDP            372268.0       1.0
# 1              39.0                INC            257181.0       2.0
# 2              59.0               PRAP            112930.0       3.0
# 3              55.0                BJP             57931.0       4.0
# 4              50.0                BSP             16471.0       5.0
# ...             ...                ...                 ...       ...
# 8789           60.0                IND               465.0      27.0
# 8790           59.0         CPI(ML)(L)               438.0      28.0
# 8791           32.0                SAP               366.0      29.0
# 8792           37.0              JD(U)               309.0      30.0
# 8793           50.0                IND               198.0      31.0
#
# [16864 rows x 14 columns]

# %%
# 1. Create grand alliances
UPA = ['INC','NCP', 'RJD', 'DMK', 'IUML','JMM','JD(s)','KC(M)','RLD','RSP','CMP(J)','KC(J)','PPI','MD']
NDA = ['BJP','SS', 'LJP', 'SAD', 'RLSP','AD','PMK','NPP','AINRC','NPF','RPI(A)','BPF','JD(U)','SDF','NDPP','MNF','RIDALOS','KMDK','IJK','PNK','JSP','GJM','MGP','GFP','GVP','AJSU','IPFT','MPP','KPP','JKPC','KC(T)','BDJS','AGP','JSS','PPA','UDP','HSPDP','PSP','JRS','KVC','PNP','SBSP','KC(N)','PDF','MDPF']
Others = ['YSRCP','AAAP', 'IND', 'AIUDF', 'BLSP', 'JKPDP', 'JD(S)', 'INLD', 'CPI', 'AIMIM','KEC(M)','SWP', 'NPEP', 'JKN', 'AIFB', 'MUL', 'AUDF', 'BOPF', 'BVA', 'HJCBL','JVM','MDMK']
def myalliance(party):
    if party in UPA:
        return 'UPA'
    elif party in NDA:
        return 'NDA'
    else:
        return 'Others'
df1['alliance'] = df1['Party Abbreviation'].apply(myalliance)

df3['alliance'] = df3['Party Abbreviation'].apply(myalliance)
dfC['alliance'] = dfC['Party Abbreviation'].apply(myalliance)

# %%
df1
# Out:
#      ST_CODE      State name  Month  Year  PC Number     PC name PC Type  \
# 0        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 1        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 2        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 3        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 4        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# ...      ...             ...    ...   ...        ...         ...     ...
# 8065     U07      Puducherry      3  2009          1  Puducherry     GEN
# 8066     U07      Puducherry      3  2009          1  Puducherry     GEN
# 8067     U07      Puducherry      3  2009          1  Puducherry     GEN
# 8068     U07      Puducherry      3  2009          1  Puducherry     GEN
# 8069     U07      Puducherry      3  2009          1  Puducherry     GEN
#
#               Candidate Name Candidate Sex Candidate Category  Candidate Age  \
# 0              RATHOD RAMESH             M                 ST           43.0
# 1              KOTNAK RAMESH             M                 ST           39.0
# 2            MESRAM NAGO RAO             M                 ST           59.0
# 3                ADE TUKARAM             M                 ST           55.0
# 4       RATHOD SADASHIV NAIK             M                 ST           50.0
# ...                      ...           ...                ...            ...
# 8065        DR. R. NARAYANAN             M                GEN           59.0
# 8066  MUPPADAI MATHIMAHARAJA             M                GEN           45.0
# 8067         MURUGAIYAN. K.S             M                GEN           42.0
# 8068              I.M. SEKAR             M                GEN           46.0
# 8069     MOHAMED YOUSUF. S.A             M                GEN           46.0
#
#      Party Abbreviation  Total Votes Polled  Position alliance
# 0                   TDP            372268.0       1.0   Others
# 1                   INC            257181.0       2.0      UPA
# 2                  PRAP            112930.0       3.0   Others
# 3                   BJP             57931.0       4.0      NDA
# 4                   BSP             16471.0       5.0   Others
# ...                 ...                 ...       ...      ...
# 8065                IND               422.0      24.0   Others
# 8066                IND               378.0      25.0   Others
# 8067                IND               378.0      26.0   Others
# 8068                IND               375.0      27.0   Others
# 8069                IND               298.0      28.0   Others
#
# [8070 rows x 15 columns]

# %%
df3
# Out:
#      ST_CODE      State name  Month  Year  PC Number     PC name PC Type  \
# 0        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# 1        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# 2        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# 3        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# 4        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# ...      ...             ...    ...   ...        ...         ...     ...
# 8789     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8790     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8791     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8792     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8793     U07      Puducherry      5  2014          1  Puducherry     GEN
#
#                     Candidate Name Candidate Sex Candidate Category  \
# 0                     GODAM NAGESH             M                 ST
# 1                           NARESH             M                 ST
# 2                    RAMESH RATHOD             M                 ST
# 3                  RATHOD SADASHIV             M                 ST
# 4                 NETHAWATH RAMDAS             M                 ST
# ...                            ...           ...                ...
# 8789          PUVALA NAGESWARA RAO             M                GEN
# 8790                     G. PALANI             M                GEN
# 8791            MARIE UTHRIANATHAN             M                GEN
# 8792                 S. CHITRAKALA             F                GEN
# 8793  P. DHANARASU @ MATHIMAHARAJA             M                GEN
#
#       Candidate Age Party Abbreviation  Total Votes Polled  Position alliance
# 0              49.0                TRS              430847         1   Others
# 1              37.0                INC              259557         2      UPA
# 2              48.0                TDP              184198         3   Others
# 3              55.0                BSP               94420         4   Others
# 4              44.0                IND               41032         5   Others
# ...             ...                ...                 ...       ...      ...
# 8789           60.0                IND                 465        27   Others
# 8790           59.0         CPI(ML)(L)                 438        28   Others
# 8791           32.0                SAP                 366        29   Others
# 8792           37.0              JD(U)                 309        30      NDA
# 8793           50.0                IND                 198        31   Others
#
# [8794 rows x 15 columns]

# %%
dfC
# Out:
#      ST_CODE      State name  Month  Year  PC Number     PC name PC Type  \
# 0        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 1        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 2        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 3        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 4        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# ...      ...             ...    ...   ...        ...         ...     ...
# 8789     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8790     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8791     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8792     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8793     U07      Puducherry      5  2014          1  Puducherry     GEN
#
#                     Candidate Name Candidate Sex Candidate Category  \
# 0                    RATHOD RAMESH             M                 ST
# 1                    KOTNAK RAMESH             M                 ST
# 2                  MESRAM NAGO RAO             M                 ST
# 3                      ADE TUKARAM             M                 ST
# 4             RATHOD SADASHIV NAIK             M                 ST
# ...                            ...           ...                ...
# 8789          PUVALA NAGESWARA RAO             M                GEN
# 8790                     G. PALANI             M                GEN
# 8791            MARIE UTHRIANATHAN             M                GEN
# 8792                 S. CHITRAKALA             F                GEN
# 8793  P. DHANARASU @ MATHIMAHARAJA             M                GEN
#
#       Candidate Age Party Abbreviation  Total Votes Polled  Position alliance
# 0              43.0                TDP            372268.0       1.0   Others
# 1              39.0                INC            257181.0       2.0      UPA
# 2              59.0               PRAP            112930.0       3.0   Others
# 3              55.0                BJP             57931.0       4.0      NDA
# 4              50.0                BSP             16471.0       5.0   Others
# ...             ...                ...                 ...       ...      ...
# 8789           60.0                IND               465.0      27.0   Others
# 8790           59.0         CPI(ML)(L)               438.0      28.0   Others
# 8791           32.0                SAP               366.0      29.0   Others
# 8792           37.0              JD(U)               309.0      30.0      NDA
# 8793           50.0                IND               198.0      31.0   Others
#
# [16864 rows x 15 columns]

# %%
# 2. Create Winning seats distribution by Major Political Parties & Alliances for 2009 & 2014

#Year 2009
vc = df1['alliance'].value_counts()
print(vc)
plt.pie(vc, labels=['Others', 'NDA', 'UPA'], autopct='%1.1f%%')
plt.show()
# Out:
# Others    6676
# NDA        744
# UPA        650
# Name: alliance, dtype: int64

# %%
#Year 2014
vc2 = df3['alliance'].value_counts()
print(vc2)
plt.pie(vc2, labels=['Others', 'NDA', 'UPA'], autopct='%1.1f%%')
plt.show()
# Out:
# Others    7530
# NDA        634
# UPA        630
# Name: alliance, dtype: int64

# %%
#3. How many seats won by Alliances and Major Political Parties ?

vc1 = df1['alliance'].value_counts()
print(vc1)

vc3 = df3['alliance'].value_counts()
print(vc3)
# Out:
# Others    6676
# NDA        744
# UPA        650
# Name: alliance, dtype: int64
# Others    7530
# NDA        634
# UPA        630
# Name: alliance, dtype: int64

# %%
# 4. Plot comparatively seats won based on candidate category as General, ST and SC for 2009 & 2014

#year 2009
won_09 = df1[df1['Position'] == 1]
won_09
# Out:
#      ST_CODE      State name  Month  Year  PC Number            PC name  \
# 0        S01  Andhra Pradesh      3  2009          1           Adilabad
# 9        S01  Andhra Pradesh      3  2009          2         Peddapalle
# 24       S01  Andhra Pradesh      3  2009          3         Karimnagar
# 39       S01  Andhra Pradesh      3  2009          4          Nizamabad
# 51       S01  Andhra Pradesh      3  2009          5          Zahirabad
# ...      ...             ...    ...   ...        ...                ...
# 7992     U05    NCT OF Delhi      3  2009          5  NORTH WEST  DELHI
# 8008     U05    NCT OF Delhi      3  2009          6        WEST  DELHI
# 8023     U05    NCT OF Delhi      3  2009          7        SOUTH DELHI
# 8038     U06     Lakshadweep      3  2009          1        Lakshadweep
# 8042     U07      Puducherry      3  2009          1         Puducherry
#
#      PC Type        Candidate Name Candidate Sex Candidate Category  \
# 0         ST         RATHOD RAMESH             M                 ST
# 9         SC       DR.G.VIVEKANAND             M                 SC
# 24       GEN      PONNAM PRABHAKAR             M                GEN
# 39       GEN     MADHU YASKHI GOUD             M                GEN
# 51       GEN  SURESH KUMAR SHETKAR             M                GEN
# ...      ...                   ...           ...                ...
# 7992      SC        KRISHNA TIRATH             F                 SC
# 8008     GEN        MAHABAL MISHRA             M                GEN
# 8023     GEN          RAMESH KUMAR             M                GEN
# 8038      ST      HAMDULLAH SAYEED             M                 ST
# 8042     GEN          NARAYANASAMY             M                GEN
#
#       Candidate Age Party Abbreviation  Total Votes Polled  Position alliance
# 0              43.0                TDP            372268.0       1.0   Others
# 9              51.0                INC            313748.0       1.0      UPA
# 24             41.0                INC            317927.0       1.0      UPA
# 39             50.0                INC            296504.0       1.0      UPA
# 51             46.0                INC            395767.0       1.0      UPA
# ...             ...                ...                 ...       ...      ...
# 7992           54.0                INC            487404.0       1.0      UPA
# 8008           54.0                INC            479899.0       1.0      UPA
# 8023           53.0                INC            360278.0       1.0      UPA
# 8038           26.0                INC             20492.0       1.0      UPA
# 8042           61.0                INC            300391.0       1.0      UPA
#
# [541 rows x 15 columns]

# %%
#Year 2009
category = ['General', 'ST' , 'SC']
cat_vc_09 = won_09['Candidate Category'].value_counts()
print(cat_vc_09)

plt.pie(cat_vc_09, labels=category, autopct='%1.1f%%')
plt.show()
# Out:
# GEN    403
# SC      85
# ST      53
# Name: Candidate Category, dtype: int64

# %%
#year 2014
won_14 = df3[df3['Position'] == 1]
won_14
# Out:
#      ST_CODE      State name  Month  Year  PC Number  \
# 0        S01  Andhra Pradesh      5  2014          1
# 9        S01  Andhra Pradesh      5  2014          2
# 27       S01  Andhra Pradesh      5  2014          3
# 45       S01  Andhra Pradesh      5  2014          4
# 62       S01  Andhra Pradesh      5  2014          5
# ...      ...             ...    ...   ...        ...
# 8703     U05    NCT OF Delhi      5  2014          5
# 8718     U05    NCT OF Delhi      5  2014          6
# 8736     U05    NCT OF Delhi      5  2014          7
# 8756     U06     Lakshadweep      5  2014          1
# 8763     U07      Puducherry      5  2014          1
#
#                              PC name PC Type             Candidate Name  \
# 0                          Adilabad       ST               GODAM NAGESH
# 9                        Peddapalle       SC                BALKA SUMAN
# 27                       Karimnagar      GEN     VINOD KUMAR BOINAPALLY
# 45                         Nizamabad     GEN        KALVAKUNTLA KAVITHA
# 62                         Zahirabad     GEN                 B.B. PATIL
# ...                              ...     ...                        ...
# 8703  NORTH WEST DELHI                   SC                    UDIT RAJ
# 8718  WEST DELHI                         GEN  PARVESH SAHIB SINGH VERMA
# 8736  SOUTH DELHI                        GEN             RAMESH BIDHURI
# 8756                     Lakshadweep      ST       MOHAMMED FAIZAL P.P.
# 8763                      Puducherry     GEN           R. RADHAKRISHNAN
#
#      Candidate Sex Candidate Category  Candidate Age Party Abbreviation  \
# 0                M                 ST           49.0                TRS
# 9                M                 SC           31.0                TRS
# 27               M                GEN           54.0                TRS
# 45               F                GEN           36.0                TRS
# 62               M                GEN           58.0                TRS
# ...            ...                ...            ...                ...
# 8703             M                 SC           56.0                BJP
# 8718             M                GEN           36.0                BJP
# 8736             M                GEN           52.0                BJP
# 8756             M                 ST           38.0                NCP
# 8763             M                GEN           42.0              AINRC
#
#       Total Votes Polled  Position alliance
# 0                 430847         1   Others
# 9                 565496         1   Others
# 27                505358         1   Others
# 45                439307         1   Others
# 62                508661         1   Others
# ...                  ...       ...      ...
# 8703              629860         1      NDA
# 8718              651395         1      NDA
# 8736              497980         1      NDA
# 8756               21665         1      UPA
# 8763              255826         1      NDA
#
# [543 rows x 15 columns]

# %%
#year 2014
cat_vc_14 = won_14['Candidate Category'].value_counts()
print(cat_vc_14)
plt.pie(cat_vc_14, labels = ['General', 'SC' , 'ST'], autopct='%1.1f%%')
plt.show()
# Out:
# GEN    405
# SC      85
# ST      53
# Name: Candidate Category, dtype: int64

# %%
# 5. Plot the age distribution of winners of both 2014 and 2009 elections

#year 2009
# Plot the histogram of age distribution
plt.hist(won_09['Candidate Age'], bins=20, align='left', alpha=0.5, label='Number of Individuals')

plt.xlabel('Candidate Age')
plt.ylabel('Counts')
plt.legend()
plt.show()

# %%
# year 2014

# Plot the histogram of age distribution
plt.hist(won_14['Candidate Age'], bins=range(0, 101, 5), align='left', alpha=0.5, label='Number of Individuals')

plt.xlabel('Candidate Age')
plt.ylabel('Counts')
plt.legend()
plt.show()

# %%
# 6. Separately plot age distribution of NDA & UPA candidates
nda_data = dfC[dfC['alliance'] == 'NDA']

plt.hist(nda_data['Candidate Age'], bins=range(0, 101, 5), alpha=0.5, label='NDA Candidates')
plt.xlabel('Candidate Age')
plt.ylabel('Counts')
plt.legend()
plt.show()

# %%
# Plot age distribution for UPA candidates
upa_data = dfC[dfC['alliance'] == 'UPA']
plt.hist(upa_data['Candidate Age'], bins=range(0, 101, 5), alpha=0.5, label='UPA Candidates')

plt.xlabel('Candidate Age')
plt.ylabel('Counts')
plt.legend()
plt.show()

# %%
# 7. Plot Gender distributions of 2009 & 2014 elections

#year 2009
gender_data = dfC.groupby(['Candidate Sex','Year']).size().unstack()

gender_data.plot(kind = 'bar')
plt.xlabel('Candidate Sex')
plt.ylabel('Counts')
plt.legend()
plt.show()

# %%
# 8. Plot gender distribution of NDA and UPA separately for 2009 elections
gender_dist_09 = won_09.groupby(['alliance', 'Candidate Sex']).size().unstack()

# Plot the gender distribution for NDA and UPA in 2014
gender_dist_09.plot(kind='bar')
plt.title('Gender Distribution of NDA & UPA Candidates (2009)')
plt.xlabel('Alliance')
plt.ylabel('Number of Candidates')
plt.xticks(rotation=0)
plt.legend(title='Sex')
plt.tight_layout()
plt.show()

# %%
# 9. Plot gender distribution of NDA and UPA separately for 2014 elections
gender_dist_14 = won_14.groupby(['alliance', 'Candidate Sex']).size().unstack()

# Plot the gender distribution for NDA and UPA in 2014
gender_dist_14.plot(kind='bar')
plt.title('Gender Distribution of NDA & UPA Candidates (2014)')
plt.xlabel('Alliance')
plt.ylabel('Number of Candidates')
plt.xticks(rotation=0)
plt.legend(title='Sex')
plt.tight_layout()
plt.show()

# %%
# 10. Plot the poll percentage of states for 2009 & 2014 elections
plt.figure(figsize=(15,8))
plt.bar(df2['STATE'], df2['POLL PERCENTAGE'], width=0.4, label='2009', align='center')
plt.bar(df4['STATE'], df4['POLL PERCENTAGE'], width=0.4, label='2014', align='edge')
plt.xlabel('State name')
plt.ylabel('Poll Percentage')
plt.title('Poll Percentage of States for 2009 & 2014 Elections')
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()
plt.show()
