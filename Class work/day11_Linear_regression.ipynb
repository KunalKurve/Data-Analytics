# %%
import pandas as pd

# %%
df= pd.read_csv('salary.csv')
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
X=df.iloc[: ,:-1].values

# %%
y=df.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=1/3 ,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
print(y_pred)
# Out:
# [ 40835.10590871 123079.39940819  65134.55626083  63265.36777221
#  115602.64545369 108125.8914992  116537.23969801  64199.96201652
#   76349.68719258 100649.1375447 ]

# %%
import matplotlib.pyplot as plt
plt.scatter(X_train,y_train,color='red')
plt.plot(X_train,regressor.predict(X_train),color='blue')
plt.title('Salary vs Years of Expirence')
plt.xlabel('Years of expirience')
plt.ylabel('Salary')
plt.show()

# %%
new_salary_pred = regressor.predict([[15]])
print('The salary of a person with 15 years of expirience is :',new_salary_pred)
# Out:
# The salary of a person with 15 years of expirience is : [167005.32889087]

# %%
print('Intercept...Fesher Salary : ',regressor.intercept_)
print("Coefficient... Additional salary for each Additional year's Expirience is : ",regressor.coef_)
# Out:
# Intercept...Fesher Salary :  26816.192244031183
# Coefficient... Additional salary for each Additional year's Expirience is :  [9345.94244312]

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
import numpy as np

MAE=mean_absolute_error(y_test,y_pred)
MSE=mean_squared_error(y_test,y_pred)
RMSE=np.sqrt(MSE)

print(f"MAE : {MAE}")
print(f"MSE : {MSE}")
print(f"RMSE : {RMSE}")
# Out:
# MAE : 3426.4269374307078
# MSE : 21026037.329511296
# RMSE : 4585.4157204675885
