# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [raw]
# Q1. Import movies.csv into python using appropriate packages. Extract title, budget_musd, revenue_musd, production_companies, runtime, cast_size, from the imported dataset. Remove missing values from the dataset. Print top 20 rows for columns title, budget_musd and runtime.

# %%
df = pd.read_csv("movies.csv")
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %%
new_df = df[['title', 'budget_musd', 'revenue_musd', 'production_companies', 'runtime', 'cast_size']]
new_df
# Out:
#                              title  budget_musd  revenue_musd  \
# 0                        Toy Story         30.0    373.554033
# 1                          Jumanji         65.0    262.797249
# 2                 Grumpier Old Men          NaN           NaN
# 3                Waiting to Exhale         16.0     81.452156
# 4      Father of the Bride Part II          NaN     76.578911
# ...                            ...          ...           ...
# 44686                       Subdue          NaN           NaN
# 44687          Century of Birthing          NaN           NaN
# 44688                     Betrayal          NaN           NaN
# 44689             Satan Triumphant          NaN           NaN
# 44690                     Queerama          NaN           NaN
#
#                                     production_companies  runtime  cast_size
# 0                                Pixar Animation Studios     81.0         13
# ...

# %%
new_df1 = new_df.dropna()
new_df1
# Out:
#                    title  budget_musd  revenue_musd  \
# 0              Toy Story         30.0    373.554033
# 1                Jumanji         65.0    262.797249
# 3      Waiting to Exhale         16.0     81.452156
# 5                   Heat         60.0    187.436818
# 8           Sudden Death         35.0     64.350171
# ...                  ...          ...           ...
# 44256     The Dark Tower         60.0     71.000000
# 44374    The Emoji Movie         50.0     66.913939
# 44400         Wind River         11.0    184.770205
# 44482   Sivaji: The Boss         12.0     19.000000
# 44638        Pro Lyuboff          2.0      1.268793
#
#                                     production_companies  runtime  cast_size
# 0                                Pixar Animation Studios     81.0         13
# 1      TriStar Pictures|Teitler Film|Interscope Commu...    104.0         26
# 3                 Twentieth Century Fox Film Corporation    127.0         10
# ...

# %%
new_df1[['title','budget_musd','runtime']].head(20)
# Out:
#                              title  budget_musd  runtime
# 0                        Toy Story        30.00     81.0
# 1                          Jumanji        65.00    104.0
# 3                Waiting to Exhale        16.00    127.0
# 5                             Heat        60.00    170.0
# 8                     Sudden Death        35.00    106.0
# 9                        GoldenEye        58.00    130.0
# 10          The American President        62.00    106.0
# 13                           Nixon        44.00    192.0
# 14                Cutthroat Island        98.00    119.0
# 15                          Casino        52.00    178.0
# 16           Sense and Sensibility        16.50    136.0
# 17                      Four Rooms         4.00     98.0
# 18  Ace Ventura: When Nature Calls        30.00     90.0
# 19                     Money Train        60.00    103.0
# 20                      Get Shorty        30.25    105.0
# ...

# %% [raw]
# Q2. Impute median in missing data of vote_average column in dataset and then perform an outlier detection on it and create a box-plot

# %%
median_vote = df['vote_average'].median()
print(median_vote)
df['vote_average'].fillna(median_vote, inplace = True)
print(df['vote_average'])
# Out:
# 6.1
# 0        7.7
# 1        6.9
# 2        6.5
# 3        6.1
# 4        5.7
#         ...
# 44686    4.0
# 44687    9.0
# 44688    3.8
# 44689    6.1
# 44690    6.1
# Name: vote_average, Length: 44691, dtype: float64

# %%
#Outlier Detection
q1 = df['vote_average'].quantile(0.25)
q3 = df['vote_average'].quantile(0.75)
iqr = q3-q1 

lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

outliers = df[(df['vote_average'] < lower_bound) | (df['vote_average'] > upper_bound)]['vote_average']

# %%
plt.figure(figsize = (8,6))
sns.boxplot(x = 'vote_average', data = df, showfliers = True, medianprops = dict(color = 'red'), 
           flierprops = dict(marker = 'o', markerfacecolor = 'red', markersize = 8))
plt.scatter(x = [0.5], y = [median_vote], color = 'red', s = 100, label = 'Median')
plt.axvline(x = q1, linestyle = '--', color = 'blue', label = 'Q1')
plt.axvline(x = q3, linestyle = '--', color = 'blue', label = 'Q3')
plt.axvline(x = lower_bound, linestyle = '--', color = 'green', label = 'Lower Bound')
plt.axvline(x = upper_bound, linestyle = '--', color = 'green', label = 'Upper Bound')
plt.legend()
plt.title('Box Plot of Average Vote')
plt.show()

# %%
#Boxplot
sns.boxplot(x='vote_average', data = df)
plt.show()

# %% [raw]
# Q3. Find the column which has maximum missing data in it. For that column update the missing data with the mean of the cast_size value.

# %% [raw]
# Q4. Calculate mean, median, mode, quartile ranges, standard deviation of runtime for where "spoken_languages" column contains only English, where crew_size > cast_size.
