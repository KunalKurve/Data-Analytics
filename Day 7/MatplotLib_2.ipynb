# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Create a sample data set

# %%
df_filtered = pd.DataFrame({
    'opposition': ['India', 'Australia', 'England', 'South Africa'],
    'runs_scored': [250, 300, 220, 280]
})

# %%
df_grouped = df_filtered.groupby('opposition')['runs_scored'].sum()

# %% [markdown]
# Create a pie plot

# %%
plt.figure(figsize = (8,6))
plt.pie(df_grouped, labels = df_grouped.index, autopct = '%1.1f%%')
plt.title('Total Runs Scored Against each Opposition')
plt.show()

# %% [markdown]
# ## μ(mu) & σ(sigma) & π(pi) are the symbols of Population Parameters - MCQ for CCE
